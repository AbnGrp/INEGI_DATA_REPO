# %% [markdown]
# # Census of population: INEGI 2020 (EDA)

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from eda_functions import *

# %%
df=pd.read_csv(r"C:\Users\diego\OneDrive\Escritorio\INEGI_MR2\Cleaned_Data\Main_Data.csv")

# %%
df.head(3)
# Out:
#    ENTIDAD  MUN     LOC       POBTOT      POBFEM      POBMAS      P_0A2  \
# 0      0.0  0.0     0.0  126014024.0  64540634.0  61473390.0  5764054.0
# 1      0.0  0.0  9998.0     250354.0     96869.0    153485.0    10493.0
# 2      0.0  0.0  9999.0     147125.0     61324.0     85801.0     6798.0
#
#      P_0A2_F    P_0A2_M      P_3YMAS  ...  PAFIL_PDOM   PDER_SEGP  PDER_IMSSB  \
# 0  2848875.0  2915179.0  119976584.0  ...   1192255.0  32842765.0    958787.0
# 1     5193.0     5300.0     239441.0  ...       649.0     84849.0      2883.0
# 2     3407.0     3391.0     139757.0  ...       485.0     59445.0      1956.0
#
#    PAFIL_IPRIV  PAFIL_OTRAI      TOTHOG         NOM_ENT         NOM_MUN  \
# 0    2615213.0    1149542.0  35219141.0  Total nacional  Total nacional
# 1       3288.0       6284.0     62516.0  Total nacional  Total nacional
# 2       1300.0       1504.0     36568.0  Total nacional  Total nacional
#
#                         NOM_LOC  TAMLOC
# ...

# %%
pd.set_option("display.max_columns",121)

# %%
df.head(3)
# Out:
#    ENTIDAD  MUN     LOC       POBTOT      POBFEM      POBMAS      P_0A2  \
# 0      0.0  0.0     0.0  126014024.0  64540634.0  61473390.0  5764054.0
# 1      0.0  0.0  9998.0     250354.0     96869.0    153485.0    10493.0
# 2      0.0  0.0  9999.0     147125.0     61324.0     85801.0     6798.0
#
#      P_0A2_F    P_0A2_M      P_3YMAS   P_3YMAS_F   P_3YMAS_M      P_5YMAS  \
# 0  2848875.0  2915179.0  119976584.0  61554567.0  58422017.0  115693273.0
# 1     5193.0     5300.0     239441.0     91463.0    147978.0     232086.0
# 2     3407.0     3391.0     139757.0     57628.0     82129.0     135028.0
#
#     P_5YMAS_F   P_5YMAS_M     P_12YMAS  P_12YMAS_F  P_12YMAS_M    P_15YMAS  \
# 0  59433559.0  56259714.0  100528155.0  51962264.0  48565891.0  93985354.0
# 1     87931.0    144155.0     207748.0     76111.0    131637.0    197411.0
# 2     55256.0     79772.0     119223.0     47543.0     71680.0    111530.0
#
# ...

# %%
df_0=df[df["ENTIDAD"]==0.0]

# %%
df_0.head(3)
# Out:
#    ENTIDAD  MUN     LOC       POBTOT      POBFEM      POBMAS      P_0A2  \
# 0      0.0  0.0     0.0  126014024.0  64540634.0  61473390.0  5764054.0
# 1      0.0  0.0  9998.0     250354.0     96869.0    153485.0    10493.0
# 2      0.0  0.0  9999.0     147125.0     61324.0     85801.0     6798.0
#
#      P_0A2_F    P_0A2_M      P_3YMAS   P_3YMAS_F   P_3YMAS_M      P_5YMAS  \
# 0  2848875.0  2915179.0  119976584.0  61554567.0  58422017.0  115693273.0
# 1     5193.0     5300.0     239441.0     91463.0    147978.0     232086.0
# 2     3407.0     3391.0     139757.0     57628.0     82129.0     135028.0
#
#     P_5YMAS_F   P_5YMAS_M     P_12YMAS  P_12YMAS_F  P_12YMAS_M    P_15YMAS  \
# 0  59433559.0  56259714.0  100528155.0  51962264.0  48565891.0  93985354.0
# 1     87931.0    144155.0     207748.0     76111.0    131637.0    197411.0
# 2     55256.0     79772.0     119223.0     47543.0     71680.0    111530.0
#
# ...

# %%
df_1=df[df["ENTIDAD"]==1.0]

# %%
df_1.head(3)
# Out:
#    ENTIDAD  MUN     LOC     POBTOT    POBFEM    POBMAS    P_0A2  P_0A2_F  \
# 3      1.0  0.0     0.0  1425607.0  728924.0  696683.0  71864.0  35604.0
# 4      1.0  0.0  9998.0     3697.0    1510.0    2187.0    165.0     81.0
# 5      1.0  0.0  9999.0     3021.0    1013.0    2008.0    119.0     54.0
#
#    P_0A2_M    P_3YMAS  P_3YMAS_F  P_3YMAS_M    P_5YMAS  P_5YMAS_F  P_5YMAS_M  \
# 3  36260.0  1352235.0   692561.0   659674.0  1299669.0   666713.0   632956.0
# 4     84.0     3532.0     1429.0     2103.0     3420.0     1377.0     2043.0
# 5     65.0     2902.0      959.0     1943.0     2829.0      925.0     1904.0
#
#     P_12YMAS  P_12YMAS_F  P_12YMAS_M   P_15YMAS  P_15YMAS_F  P_15YMAS_M  \
# 3  1116719.0    576593.0    540126.0  1038904.0    538387.0    500517.0
# 4     3018.0      1179.0      1839.0     2836.0      1086.0      1750.0
# 5     2553.0       798.0      1755.0     2444.0       740.0      1704.0
#
# ...

# %%
df_2=df[df["ENTIDAD"]==2.0]

# %%
df_2.head(3)
# Out:
#       ENTIDAD  MUN     LOC     POBTOT     POBFEM     POBMAS     P_0A2  \
# 2061      2.0  0.0     0.0  3769020.0  1868431.0  1900589.0  149957.0
# 2062      2.0  0.0  9998.0     8665.0     3479.0     5186.0     315.0
# 2063      2.0  0.0  9999.0     6167.0     2646.0     3521.0     234.0
#
#       P_0A2_F  P_0A2_M    P_3YMAS  P_3YMAS_F  P_3YMAS_M    P_5YMAS  P_5YMAS_F  \
# 2061  74010.0  75947.0  3610844.0  1790298.0  1820546.0  3494500.0  1732417.0
# 2062    173.0    142.0     8337.0     3300.0     5037.0     8134.0     3193.0
# 2063    116.0    118.0     5923.0     2524.0     3399.0     5738.0     2429.0
#
#       P_5YMAS_M   P_12YMAS  P_12YMAS_F  P_12YMAS_M   P_15YMAS  P_15YMAS_F  \
# 2061  1762083.0  3069620.0   1524170.0   1545450.0  2882498.0   1432330.0
# 2062     4941.0     7368.0      2829.0      4539.0     7029.0      2668.0
# 2063     3309.0     5152.0      2147.0      3005.0     4921.0      2042.0
#
# ...

# %%
df_3=df[df["ENTIDAD"]==3.0]

# %%
df_4=df[df["ENTIDAD"]==4.0]

# %%
df_5=df[df["ENTIDAD"]==5.0]

# %%
df_6=df[df["ENTIDAD"]==6.0]

# %%
df_7=df[df["ENTIDAD"]==7.0]

# %%
df_8=df[df["ENTIDAD"]==8.0]

# %%
df_9=df[df["ENTIDAD"]==9.0]

# %%
df_10=df[df["ENTIDAD"]==10.0]

# %%
df_11=df[df["ENTIDAD"]==11.0]

# %%
df_12=df[df["ENTIDAD"]==12.0]

# %%
df_13=df[df["ENTIDAD"]==13.0]

# %%
df_14=df[df["ENTIDAD"]==14.0]

# %%
df_15=df[df["ENTIDAD"]==15.0]

# %%
df_16=df[df["ENTIDAD"]==16.0]

# %%
df_17=df[df["ENTIDAD"]==17.0]

# %%
df_18=df[df["ENTIDAD"]==18.0]

# %%
df_19=df[df["ENTIDAD"]==19.0]

# %%
df_20=df[df["ENTIDAD"]==20.0]

# %%
df_21=df[df["ENTIDAD"]==21.0]

# %%
df_22=df[df["ENTIDAD"]==22.0]

# %%
df_23=df[df["ENTIDAD"]==23.0]

# %%
df_24=df[df["ENTIDAD"]==24.0]

# %%
df_25=df[df["ENTIDAD"]==25.0]

# %%
df_26=df[df["ENTIDAD"]==26.0]

# %%
df_27=df[df["ENTIDAD"]==27.0]

# %%
df_28=df[df["ENTIDAD"]==28.0]

# %%
df_29=df[df["ENTIDAD"]==29.0]

# %%
df_30=df[df["ENTIDAD"]==30.0]

# %%
df_31=df[df["ENTIDAD"]==31.0]

# %%
df_32=df[df["ENTIDAD"]==32.0]

# %%
df_tpop=pd.DataFrame({""})

# %%
datafs=[df_0,df_1,df_2,df_3,df_4,df_5,df_6,df_7,df_8,df_9,df_10,df_11,df_12,df_13,df_14,df_15,df_16,df_17,df_18,df_19,df_20,df_21,df_22,df_23,df_24,df_25,df_26,df_27,df_28,df_29,df_30,df_31,df_32]

for dataframe in datafs:
    df_tpop=df_tpop.append(dataframe.iloc[0],ignore_index=True)
# Out:
# C:\Users\diego\AppData\Local\Temp\ipykernel_87528\2194497788.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tpop=df_tpop.append(dataframe.iloc[0],ignore_index=True)
# C:\Users\diego\AppData\Local\Temp\ipykernel_87528\2194497788.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tpop=df_tpop.append(dataframe.iloc[0],ignore_index=True)
# C:\Users\diego\AppData\Local\Temp\ipykernel_87528\2194497788.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_tpop=df_tpop.append(dataframe.iloc[0],ignore_index=True)
# C:\Users\diego\AppData\Local\Temp\ipykernel_87528\2194497788.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df_tpop.head(3)
# Out:
#      0  ENTIDAD  MUN  LOC       POBTOT      POBFEM      POBMAS      P_0A2  \
# 0           NaN  NaN  NaN          NaN         NaN         NaN        NaN
# 1  NaN      0.0  0.0  0.0  126014024.0  64540634.0  61473390.0  5764054.0
# 2  NaN      1.0  0.0  0.0    1425607.0    728924.0    696683.0    71864.0
#
#      P_0A2_F    P_0A2_M      P_3YMAS   P_3YMAS_F   P_3YMAS_M      P_5YMAS  \
# 0        NaN        NaN          NaN         NaN         NaN          NaN
# 1  2848875.0  2915179.0  119976584.0  61554567.0  58422017.0  115693273.0
# 2    35604.0    36260.0    1352235.0    692561.0    659674.0    1299669.0
#
#     P_5YMAS_F   P_5YMAS_M     P_12YMAS  P_12YMAS_F  P_12YMAS_M    P_15YMAS  \
# 0         NaN         NaN          NaN         NaN         NaN         NaN
# 1  59433559.0  56259714.0  100528155.0  51962264.0  48565891.0  93985354.0
# 2    666713.0    632956.0    1116719.0    576593.0    540126.0   1038904.0
#
# ...

# %%
df_tpop.drop(columns={0},inplace=True)

# %%
df_tpop.head(3)
# Out:
#    ENTIDAD  MUN  LOC       POBTOT      POBFEM      POBMAS      P_0A2  \
# 0      NaN  NaN  NaN          NaN         NaN         NaN        NaN
# 1      0.0  0.0  0.0  126014024.0  64540634.0  61473390.0  5764054.0
# 2      1.0  0.0  0.0    1425607.0    728924.0    696683.0    71864.0
#
#      P_0A2_F    P_0A2_M      P_3YMAS   P_3YMAS_F   P_3YMAS_M      P_5YMAS  \
# 0        NaN        NaN          NaN         NaN         NaN          NaN
# 1  2848875.0  2915179.0  119976584.0  61554567.0  58422017.0  115693273.0
# 2    35604.0    36260.0    1352235.0    692561.0    659674.0    1299669.0
#
#     P_5YMAS_F   P_5YMAS_M     P_12YMAS  P_12YMAS_F  P_12YMAS_M    P_15YMAS  \
# 0         NaN         NaN          NaN         NaN         NaN         NaN
# 1  59433559.0  56259714.0  100528155.0  51962264.0  48565891.0  93985354.0
# 2    666713.0    632956.0    1116719.0    576593.0    540126.0   1038904.0
#
#    P_15YMAS_F  P_15YMAS_M    P_18YMAS  P_18YMAS_F  P_18YMAS_M      P_3A5  \
# ...

# %%
df_tpop=df_tpop.drop(index=0)

# %%
df_tpop.head(3)
# Out:
#    ENTIDAD  MUN  LOC       POBTOT      POBFEM      POBMAS      P_0A2  \
# 1      0.0  0.0  0.0  126014024.0  64540634.0  61473390.0  5764054.0
# 2      1.0  0.0  0.0    1425607.0    728924.0    696683.0    71864.0
# 3      2.0  0.0  0.0    3769020.0   1868431.0   1900589.0   149957.0
#
#      P_0A2_F    P_0A2_M      P_3YMAS   P_3YMAS_F   P_3YMAS_M      P_5YMAS  \
# 1  2848875.0  2915179.0  119976584.0  61554567.0  58422017.0  115693273.0
# 2    35604.0    36260.0    1352235.0    692561.0    659674.0    1299669.0
# 3    74010.0    75947.0    3610844.0   1790298.0   1820546.0    3494500.0
#
#     P_5YMAS_F   P_5YMAS_M     P_12YMAS  P_12YMAS_F  P_12YMAS_M    P_15YMAS  \
# 1  59433559.0  56259714.0  100528155.0  51962264.0  48565891.0  93985354.0
# 2    666713.0    632956.0    1116719.0    576593.0    540126.0   1038904.0
# 3   1732417.0   1762083.0    3069620.0   1524170.0   1545450.0   2882498.0
#
#    P_15YMAS_F  P_15YMAS_M    P_18YMAS  P_18YMAS_F  P_18YMAS_M      P_3A5  \
# ...

# %%
df_tpop.shape
# Out:
# (33, 121)

# %%
df_tpop.sort_values(by="POBTOT",ascending=False,ignore_index=False,inplace=True)

# %%
df_tpop.head(3)
# Out:
#     ENTIDAD  MUN  LOC       POBTOT      POBFEM      POBMAS      P_0A2  \
# 32      0.0  0.0  0.0  126014024.0  64540634.0  61473390.0  5764054.0
# 31     15.0  0.0  0.0   16992418.0   8741123.0   8251295.0   724133.0
# 30      9.0  0.0  0.0    9209944.0   4805017.0   4404927.0   267151.0
#
#       P_0A2_F    P_0A2_M      P_3YMAS   P_3YMAS_F   P_3YMAS_M      P_5YMAS  \
# 32  2848875.0  2915179.0  119976584.0  61554567.0  58422017.0  115693273.0
# 31   357766.0   366367.0   16260058.0   8379157.0   7880901.0   15707805.0
# 30   131720.0   135431.0    8933167.0   4668454.0   4264713.0    8720414.0
#
#      P_5YMAS_F   P_5YMAS_M     P_12YMAS  P_12YMAS_F  P_12YMAS_M    P_15YMAS  \
# 32  59433559.0  56259714.0  100528155.0  51962264.0  48565891.0  93985354.0
# 31   8105314.0   7602491.0   13742847.0   7137483.0   6605364.0  12862124.0
# 30   4563147.0   4157267.0    7915499.0   4167530.0   3747969.0   7547545.0
#
# ...

# %%
barp(df_tpop[df_tpop["NOM_ENT"]!="Total nacional"]["POBTOT"],df_tpop[df_tpop["NOM_ENT"]!="Total nacional"]["NOM_ENT"],"Total Population Per State (2020)")
plt.xlabel("POPULATION")
plt.ylabel("STATE")
# Out:
# Text(0, 0.5, 'STATE')

# %%
barp(["Male","Female"],df_tpop.loc[0,["POBFEM","POBMAS"]],"Total Population by Gender (2020)")
plt.xlabel("GENDER")
plt.ylabel("POPULATION")
# Out:
# Text(0, 0.5, 'POPULATION')

# %%
df_tpop.head(3)
# Out:
#     ENTIDAD  MUN  LOC       POBTOT      POBFEM      POBMAS      P_0A2  \
# 32      0.0  0.0  0.0  126014024.0  64540634.0  61473390.0  5764054.0
# 31     15.0  0.0  0.0   16992418.0   8741123.0   8251295.0   724133.0
# 30      9.0  0.0  0.0    9209944.0   4805017.0   4404927.0   267151.0
#
#       P_0A2_F    P_0A2_M      P_3YMAS   P_3YMAS_F   P_3YMAS_M      P_5YMAS  \
# 32  2848875.0  2915179.0  119976584.0  61554567.0  58422017.0  115693273.0
# 31   357766.0   366367.0   16260058.0   8379157.0   7880901.0   15707805.0
# 30   131720.0   135431.0    8933167.0   4668454.0   4264713.0    8720414.0
#
#      P_5YMAS_F   P_5YMAS_M     P_12YMAS  P_12YMAS_F  P_12YMAS_M    P_15YMAS  \
# 32  59433559.0  56259714.0  100528155.0  51962264.0  48565891.0  93985354.0
# 31   8105314.0   7602491.0   13742847.0   7137483.0   6605364.0  12862124.0
# 30   4563147.0   4157267.0    7915499.0   4167530.0   3747969.0   7547545.0
#
# ...

# %%
df_fm=df_tpop[["NOM_ENT","POBMAS"]].copy()

# %%
df_fm.head(3)
# Out:
#              NOM_ENT      POBMAS
# 32    Total nacional  61473390.0
# 31            México   8251295.0
# 30  Ciudad de México   4404927.0

# %%
df_fm["GENDER"]="MALE"

# %%
df_fm.head(3)
# Out:
#              NOM_ENT      POBMAS GENDER
# 32    Total nacional  61473390.0   MALE
# 31            México   8251295.0   MALE
# 30  Ciudad de México   4404927.0   MALE

# %%
df_fm2=df_tpop[["NOM_ENT","POBFEM"]].copy()

# %%
df_fm2["GENDER"]="FEMALE"

# %%
df_fm2.head(3)
# Out:
#              NOM_ENT      POBFEM  GENDER
# 32    Total nacional  64540634.0  FEMALE
# 31            México   8741123.0  FEMALE
# 30  Ciudad de México   4805017.0  FEMALE

# %%
series_ent=[i for i in df_fm2["NOM_ENT"]]

# %%
series_ent2=series_ent*2

# %%
df_fm_final=pd.DataFrame({"NOM_ENT":series_ent2,"POB":pd.concat([df_fm["POBMAS"],df_fm2["POBFEM"]]),"GENDER":pd.concat([df_fm["GENDER"],df_fm2["GENDER"]])})

# %%
df_fm_final.head(3)
# Out:
#              NOM_ENT         POB GENDER
# 32    Total nacional  61473390.0   MALE
# 31            México   8251295.0   MALE
# 30  Ciudad de México   4404927.0   MALE

# %%
df_fm_final.sort_values(by="NOM_ENT",ascending=True,inplace=True)

# %%
df_fm_final.head(3)
# Out:
#             NOM_ENT        POB  GENDER
# 55   Aguascalientes   696683.0    MALE
# 54   Aguascalientes   728924.0  FEMALE
# 24  Baja California  1868431.0  FEMALE

# %%
df_fm_final.reset_index(inplace=True)

# %%
df_fm_final.head(3)
# Out:
#    index          NOM_ENT        POB  GENDER
# 0     55   Aguascalientes   696683.0    MALE
# 1     54   Aguascalientes   728924.0  FEMALE
# 2     24  Baja California  1868431.0  FEMALE

# %%
df_fm_final.drop(columns={"index"},inplace=True)

# %%
df_fm_final.head(3)
# Out:
#            NOM_ENT        POB  GENDER
# 0   Aguascalientes   696683.0    MALE
# 1   Aguascalientes   728924.0  FEMALE
# 2  Baja California  1868431.0  FEMALE

# %%
df_fm_final.loc[0:8,:]
# Out:
#                NOM_ENT        POB  GENDER
# 0       Aguascalientes   696683.0    MALE
# 1       Aguascalientes   728924.0  FEMALE
# 2      Baja California  1868431.0  FEMALE
# 3      Baja California  1900589.0    MALE
# 4  Baja California Sur   392568.0  FEMALE
# 5  Baja California Sur   405879.0    MALE
# 6             Campeche   456939.0    MALE
# 7             Campeche   471424.0  FEMALE
# 8              Chiapas  2837881.0  FEMALE

# %%
plt.title("Population Per State (Male vs Female) 2020")
sns.barplot(y=df_fm_final.loc[0:9,:]["POB"],x=df_fm_final.loc[0:9,:]["NOM_ENT"],hue=df_fm_final.loc[0:9,:]["GENDER"])
plt.xlabel("STATE")
plt.ylabel("POPULATION")
# Out:
# Text(0, 0.5, 'POPULATION')

# %%
plt.title("Population Per State (Male vs Female) 2020")
sns.barplot(y=df_fm_final.loc[10:19,:]["POB"],x=df_fm_final.loc[10:19,:]["NOM_ENT"],hue=df_fm_final.loc[10:19,:]["GENDER"])
plt.xlabel("STATE")
plt.ylabel("POPULATION")
# Out:
# Text(0, 0.5, 'POPULATION')

# %%
plt.title("Population Per State (Male vs Female) 2020")
sns.barplot(y=df_fm_final.loc[20:29,:]["POB"],x=df_fm_final.loc[20:29,:]["NOM_ENT"],hue=df_fm_final.loc[20:29,:]["GENDER"])
plt.xlabel("STATE")
plt.ylabel("POPULATION")
# Out:
# Text(0, 0.5, 'POPULATION')

# %%
plt.title("Population Per State (Male vs Female) 2020")
sns.barplot(y=df_fm_final.loc[30:39,:]["POB"],x=df_fm_final.loc[30:39,:]["NOM_ENT"],hue=df_fm_final.loc[30:39,:]["GENDER"])
plt.xlabel("STATE")
plt.ylabel("POPULATION")
# Out:
# Text(0, 0.5, 'POPULATION')

# %%
plt.title("Population Per State (Male vs Female) 2020")
sns.barplot(y=df_fm_final.loc[40:49,:]["POB"],x=df_fm_final.loc[40:49,:]["NOM_ENT"],hue=df_fm_final.loc[40:49,:]["GENDER"])
plt.xlabel("STATE")
plt.ylabel("POPULATION")
# Out:
# Text(0, 0.5, 'POPULATION')

# %%
plt.title("Population Per State (Male vs Female) 2020")
sns.barplot(y=df_fm_final.loc[50:57,:]["POB"],x=df_fm_final.loc[50:57,:]["NOM_ENT"],hue=df_fm_final.loc[50:57,:]["GENDER"])
plt.xlabel("STATE")
plt.ylabel("POPULATION")
# Out:
# Text(0, 0.5, 'POPULATION')

# %%
plt.title("Population Per State (Male vs Female) 2020")
sns.barplot(y=df_fm_final.loc[60:65,:]["POB"],x=df_fm_final.loc[60:65,:]["NOM_ENT"],hue=df_fm_final.loc[60:65,:]["GENDER"])
plt.xlabel("STATE")
plt.ylabel("POPULATION")
# Out:
# Text(0, 0.5, 'POPULATION')
